# %% [markdown]
# # Import and intiating

# %%
import os 
from skimage.io import imread
from tensorflow import keras 
import numpy as np
data_dir = r"C:\Users\omtam\Downloads\Keras\KArSL_18Frames_resized"
Classes_list = os.listdir(os.path.join(data_dir,"01","train"))
IMG_SIZE = 256

# %% [markdown]
# # Upsampling missing frames

# %%
def frames_downUpSamples(vidoeFrames, nFramesTarget):
    """ Adjust number of frames (eg 123) to nFramesTarget (eg 79)
    works also if originally less frames then nFramesTarget
    """
    nSamples, _, _, _ = vidoeFrames.shape
    if nSamples == nFramesTarget: return vidoeFrames

    # down/upsample the list of frames
    fraction = nSamples / nFramesTarget
    index = [int(fraction * i) for i in range(nFramesTarget)]
    frames = [vidoeFrames[i,:,:,:] for i in index]

    return np.array(frames)

# %% [markdown]
# # Feature extractor

# %% [markdown]
# # InceptionV3

# %%
def build_feature_extractor():
    InceptionV3_model = keras.applications.InceptionV3(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))

    # preprocess the input
    preprocess_input = keras.applications.inception_v3.preprocess_input(inputs)

    # extract the features from the preprocessed input
    outputs = InceptionV3_model(preprocess_input)

    # form the final model 
    myModel = keras.Model(inputs, outputs, name="feature_extractor")
    
    return myModel


feature_extractor = build_feature_extractor()

# %% [markdown]
# # EfficientNetB2

# %%
def build_feature_extractor_EfficientNetB2():
    EfficientNetB2_model = keras.applications.EfficientNetB2(
        weights="imagenet",
        include_top=False,
        pooling="avg",
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
    )

    inputs = keras.Input((IMG_SIZE, IMG_SIZE, 3))

    # preprocess the input
    preprocess_input = keras.applications.efficientnet.preprocess_input(inputs)

    # extract the features from the preprocessed input
    outputs = EfficientNetB2_model(preprocess_input)

    # form the final model 
    myModel = keras.Model(inputs, outputs, name="feature_extractor")
    
    return myModel


feature_extractor_EfficientNetB2 = build_feature_extractor_EfficientNetB2()

# %% [markdown]
# # Creating datasets for each signer ( InceptionV3 / EfficientNetB2 )

# %%
def create_dataset(signer,dataset,model):
    #Note: empty bracet for deleting previous initiations
    features = []
    labels = []
    videoFrames = []
    allVideosFeatures =[]
    videoFeatures = []
    #iteration through the classes folders
    for class_name in Classes_list:
        print(f'Extracting data of class: {class_name}')
        files_list = os.listdir(os.path.join(data_dir,signer,dataset,class_name)) 
        #iteration through the video folders
        for file_name in files_list:
            files_images = os.listdir(os.path.join(data_dir,signer,dataset,class_name,file_name))
            #read all frames inside video folder
            for images in files_images:
                images_path = os.path.join(data_dir,signer,dataset,class_name,file_name,images)
                image = imread(images_path)
                features.append(image)
            #extracting all the features from the video
            #Note: empty bracet for deleting previous initiations 
            labels.append(int(class_name)-71)
            videoFrames = frames_downUpSamples(np.array(features), 18)
            features = []
            #Extract the data using inceptionV3
            if model == 1 : videoFeatures = feature_extractor.predict(videoFrames, verbose=0)
            #Extract the data using EfficientNetB2
            if model == 2 : videoFeatures = feature_extractor_EfficientNetB2.predict(videoFrames, verbose=0)
            videoFrames = []
            allVideosFeatures.append(videoFeatures.squeeze())
            videoFeatures = []
    print("The extraction for signer ", signer ," " ,dataset, " dataset is complete" )
    return np.array(allVideosFeatures),np.array(labels)

# %% [markdown]
# # Extract the data

# %%
signer_1_train_features , signer_1_train_labels = create_dataset("01","train",1)
signer_1_test_features , signer_1_test_labels = create_dataset("01","test",1)

signer_2_train_features , signer_2_train_labels = create_dataset("02","train",1)
signer_2_test_features , signer_2_test_labels = create_dataset("02","test",1)

signer_3_train_features , signer_3_train_labels = create_dataset("03","train",1)
signer_3_test_features , signer_3_test_labels = create_dataset("03","test",1)
# Out:
# Extracting data of class: 0071
# Extracting data of class: 0072
# Extracting data of class: 0073
# Extracting data of class: 0074
# Extracting data of class: 0075
# Extracting data of class: 0076
# Extracting data of class: 0077
# Extracting data of class: 0078
# Extracting data of class: 0079
# Extracting data of class: 0080
# Extracting data of class: 0081
# Extracting data of class: 0082
# Extracting data of class: 0083
# Extracting data of class: 0084
# Extracting data of class: 0085
# Extracting data of class: 0086
# Extracting data of class: 0087
# Extracting data of class: 0088
# Extracting data of class: 0089
# Extracting data of class: 0090
# Extracting data of class: 0091
# Extracting data of class: 0092
# Extracting data of class: 0093
# Extracting data of class: 0094
# Extracting data of class: 0095
# Extracting data of class: 0096
# Extracting data of class: 0097
# Extracting data of class: 0098
# Extracting data of class: 0099
# Extracting data of class: 0100
# Extracting data of class: 0101
# Extracting data of class: 0102
# Extracting data of class: 0103
# Extracting data of class: 0104
# Extracting data of class: 0105
# Extracting data of class: 0106
# Extracting data of class: 0107
# Extracting data of class: 0108
# Extracting data of class: 0109
# Extracting data of class: 0110
# Extracting data of class: 0111
# Extracting data of class: 0112
# Extracting data of class: 0113
# Extracting data of class: 0114
# Extracting data of class: 0115
# Extracting data of class: 0116
# Extracting data of class: 0117
# Extracting data of class: 0118
# Extracting data of class: 0119
# Extracting data of class: 0120
# Extracting data of class: 0121
# Extracting data of class: 0122
# Extracting data of class: 0123
# Extracting data of class: 0124
# Extracting data of class: 0125
# Extracting data of class: 0126
# Extracting data of class: 0127
# Extracting data of class: 0128
# Extracting data of class: 0129
# Extracting data of class: 0130
# Extracting data of class: 0131
# Extracting data of class: 0132
# Extracting data of class: 0133
# Extracting data of class: 0134
# Extracting data of class: 0135
# Extracting data of class: 0136
# Extracting data of class: 0137
# Extracting data of class: 0138
# Extracting data of class: 0139
# Extracting data of class: 0140
# Extracting data of class: 0141
# Extracting data of class: 0142
# Extracting data of class: 0143
# Extracting data of class: 0144
# Extracting data of class: 0145
# Extracting data of class: 0146
# Extracting data of class: 0147
# Extracting data of class: 0148
# Extracting data of class: 0149
# Extracting data of class: 0150
# Extracting data of class: 0151
# Extracting data of class: 0152
# Extracting data of class: 0153
# Extracting data of class: 0154
# Extracting data of class: 0155
# Extracting data of class: 0156
# Extracting data of class: 0157
# Extracting data of class: 0158
# Extracting data of class: 0159
# Extracting data of class: 0160
# Extracting data of class: 0161
# Extracting data of class: 0162
# Extracting data of class: 0163
# Extracting data of class: 0164
# Extracting data of class: 0165
# Extracting data of class: 0166
# Extracting data of class: 0167
# Extracting data of class: 0168
# Extracting data of class: 0169
# Extracting data of class: 0170
# The extraction for signer  01   train  dataset is complete
# Extracting data of class: 0071
# Extracting data of class: 0072
# Extracting data of class: 0073
# Extracting data of class: 0074
# Extracting data of class: 0075
# Extracting data of class: 0076
# Extracting data of class: 0077
# Extracting data of class: 0078
# Extracting data of class: 0079
# Extracting data of class: 0080
# Extracting data of class: 0081
# Extracting data of class: 0082
# Extracting data of class: 0083
# Extracting data of class: 0084
# Extracting data of class: 0085
# Extracting data of class: 0086
# Extracting data of class: 0087
# Extracting data of class: 0088
# Extracting data of class: 0089
# Extracting data of class: 0090
# Extracting data of class: 0091
# Extracting data of class: 0092
# Extracting data of class: 0093
# Extracting data of class: 0094
# Extracting data of class: 0095
# Extracting data of class: 0096
# Extracting data of class: 0097
# Extracting data of class: 0098
# Extracting data of class: 0099
# Extracting data of class: 0100
# Extracting data of class: 0101
# Extracting data of class: 0102
# Extracting data of class: 0103
# Extracting data of class: 0104
# Extracting data of class: 0105
# Extracting data of class: 0106
# Extracting data of class: 0107
# Extracting data of class: 0108
# Extracting data of class: 0109
# Extracting data of class: 0110
# Extracting data of class: 0111
# Extracting data of class: 0112
# Extracting data of class: 0113
# Extracting data of class: 0114
# Extracting data of class: 0115
# Extracting data of class: 0116
# Extracting data of class: 0117
# Extracting data of class: 0118
# Extracting data of class: 0119
# Extracting data of class: 0120
# Extracting data of class: 0121
# Extracting data of class: 0122
# Extracting data of class: 0123
# Extracting data of class: 0124
# Extracting data of class: 0125
# Extracting data of class: 0126
# Extracting data of class: 0127
# Extracting data of class: 0128
# Extracting data of class: 0129
# Extracting data of class: 0130
# Extracting data of class: 0131
# Extracting data of class: 0132
# Extracting data of class: 0133
# Extracting data of class: 0134
# Extracting data of class: 0135
# Extracting data of class: 0136
# Extracting data of class: 0137
# Extracting data of class: 0138
# Extracting data of class: 0139
# Extracting data of class: 0140
# Extracting data of class: 0141
# Extracting data of class: 0142
# Extracting data of class: 0143
# Extracting data of class: 0144
# Extracting data of class: 0145
# Extracting data of class: 0146
# Extracting data of class: 0147
# Extracting data of class: 0148
# Extracting data of class: 0149
# Extracting data of class: 0150
# Extracting data of class: 0151
# Extracting data of class: 0152
# Extracting data of class: 0153
# Extracting data of class: 0154
# Extracting data of class: 0155
# Extracting data of class: 0156
# Extracting data of class: 0157
# Extracting data of class: 0158
# Extracting data of class: 0159
# Extracting data of class: 0160
# Extracting data of class: 0161
# Extracting data of class: 0162
# Extracting data of class: 0163
# Extracting data of class: 0164
# Extracting data of class: 0165
# Extracting data of class: 0166
# Extracting data of class: 0167
# Extracting data of class: 0168
# Extracting data of class: 0169
# Extracting data of class: 0170
# The extraction for signer  01   test  dataset is complete
# Extracting data of class: 0071
# Extracting data of class: 0072
# Extracting data of class: 0073
# Extracting data of class: 0074
# Extracting data of class: 0075
# Extracting data of class: 0076
# Extracting data of class: 0077
# Extracting data of class: 0078
# Extracting data of class: 0079
# Extracting data of class: 0080
# Extracting data of class: 0081
# Extracting data of class: 0082
# Extracting data of class: 0083
# Extracting data of class: 0084
# Extracting data of class: 0085
# Extracting data of class: 0086
# Extracting data of class: 0087
# Extracting data of class: 0088
# Extracting data of class: 0089
# Extracting data of class: 0090
# Extracting data of class: 0091
# Extracting data of class: 0092
# Extracting data of class: 0093
# Extracting data of class: 0094
# Extracting data of class: 0095
# Extracting data of class: 0096
# Extracting data of class: 0097
# Extracting data of class: 0098
# Extracting data of class: 0099
# Extracting data of class: 0100
# Extracting data of class: 0101
# Extracting data of class: 0102
# Extracting data of class: 0103
# Extracting data of class: 0104
# Extracting data of class: 0105
# Extracting data of class: 0106
# Extracting data of class: 0107
# Extracting data of class: 0108
# Extracting data of class: 0109
# Extracting data of class: 0110
# Extracting data of class: 0111
# Extracting data of class: 0112
# Extracting data of class: 0113
# Extracting data of class: 0114
# Extracting data of class: 0115
# Extracting data of class: 0116
# Extracting data of class: 0117
# Extracting data of class: 0118
# Extracting data of class: 0119
# Extracting data of class: 0120
# Extracting data of class: 0121
# Extracting data of class: 0122
# Extracting data of class: 0123
# Extracting data of class: 0124
# Extracting data of class: 0125
# Extracting data of class: 0126
# Extracting data of class: 0127
# Extracting data of class: 0128
# Extracting data of class: 0129
# Extracting data of class: 0130
# Extracting data of class: 0131
# Extracting data of class: 0132
# Extracting data of class: 0133
# Extracting data of class: 0134
# Extracting data of class: 0135
# Extracting data of class: 0136
# Extracting data of class: 0137
# Extracting data of class: 0138
# Extracting data of class: 0139
# Extracting data of class: 0140
# Extracting data of class: 0141
# Extracting data of class: 0142
# Extracting data of class: 0143
# Extracting data of class: 0144
# Extracting data of class: 0145
# Extracting data of class: 0146
# Extracting data of class: 0147
# Extracting data of class: 0148
# Extracting data of class: 0149
# Extracting data of class: 0150
# Extracting data of class: 0151
# Extracting data of class: 0152
# Extracting data of class: 0153
# Extracting data of class: 0154
# Extracting data of class: 0155
# Extracting data of class: 0156
# Extracting data of class: 0157
# Extracting data of class: 0158
# Extracting data of class: 0159
# Extracting data of class: 0160
# Extracting data of class: 0161
# Extracting data of class: 0162
# Extracting data of class: 0163
# Extracting data of class: 0164
# Extracting data of class: 0165
# Extracting data of class: 0166
# Extracting data of class: 0167
# Extracting data of class: 0168
# Extracting data of class: 0169
# Extracting data of class: 0170
# The extraction for signer  02   train  dataset is complete
# Extracting data of class: 0071
# Extracting data of class: 0072
# Extracting data of class: 0073
# Extracting data of class: 0074
# Extracting data of class: 0075
# Extracting data of class: 0076
# Extracting data of class: 0077
# Extracting data of class: 0078
# Extracting data of class: 0079
# Extracting data of class: 0080
# Extracting data of class: 0081
# Extracting data of class: 0082
# Extracting data of class: 0083
# Extracting data of class: 0084
# Extracting data of class: 0085
# Extracting data of class: 0086
# Extracting data of class: 0087
# Extracting data of class: 0088
# Extracting data of class: 0089
# Extracting data of class: 0090
# Extracting data of class: 0091
# Extracting data of class: 0092
# Extracting data of class: 0093
# Extracting data of class: 0094
# Extracting data of class: 0095
# Extracting data of class: 0096
# Extracting data of class: 0097
# Extracting data of class: 0098
# Extracting data of class: 0099
# Extracting data of class: 0100
# Extracting data of class: 0101
# Extracting data of class: 0102
# Extracting data of class: 0103
# Extracting data of class: 0104
# Extracting data of class: 0105
# Extracting data of class: 0106
# Extracting data of class: 0107
# Extracting data of class: 0108
# Extracting data of class: 0109
# Extracting data of class: 0110
# Extracting data of class: 0111
# Extracting data of class: 0112
# Extracting data of class: 0113
# Extracting data of class: 0114
# Extracting data of class: 0115
# Extracting data of class: 0116
# Extracting data of class: 0117
# Extracting data of class: 0118
# Extracting data of class: 0119
# Extracting data of class: 0120
# Extracting data of class: 0121
# Extracting data of class: 0122
# Extracting data of class: 0123
# Extracting data of class: 0124
# Extracting data of class: 0125
# Extracting data of class: 0126
# Extracting data of class: 0127
# Extracting data of class: 0128
# Extracting data of class: 0129
# Extracting data of class: 0130
# Extracting data of class: 0131
# Extracting data of class: 0132
# Extracting data of class: 0133
# Extracting data of class: 0134
# Extracting data of class: 0135
# Extracting data of class: 0136
# Extracting data of class: 0137
# Extracting data of class: 0138
# Extracting data of class: 0139
# Extracting data of class: 0140
# Extracting data of class: 0141
# Extracting data of class: 0142
# Extracting data of class: 0143
# Extracting data of class: 0144
# Extracting data of class: 0145
# Extracting data of class: 0146
# Extracting data of class: 0147
# Extracting data of class: 0148
# Extracting data of class: 0149
# Extracting data of class: 0150
# Extracting data of class: 0151
# Extracting data of class: 0152
# Extracting data of class: 0153
# Extracting data of class: 0154
# Extracting data of class: 0155
# Extracting data of class: 0156
# Extracting data of class: 0157
# Extracting data of class: 0158
# Extracting data of class: 0159
# Extracting data of class: 0160
# Extracting data of class: 0161
# Extracting data of class: 0162
# Extracting data of class: 0163
# Extracting data of class: 0164
# Extracting data of class: 0165
# Extracting data of class: 0166
# Extracting data of class: 0167
# Extracting data of class: 0168
# Extracting data of class: 0169
# Extracting data of class: 0170
# The extraction for signer  02   test  dataset is complete
# Extracting data of class: 0071
# Extracting data of class: 0072
# Extracting data of class: 0073
# Extracting data of class: 0074
# Extracting data of class: 0075
# Extracting data of class: 0076
# Extracting data of class: 0077
# Extracting data of class: 0078
# Extracting data of class: 0079
# Extracting data of class: 0080
# Extracting data of class: 0081
# Extracting data of class: 0082
# Extracting data of class: 0083
# Extracting data of class: 0084
# Extracting data of class: 0085
# Extracting data of class: 0086
# Extracting data of class: 0087
# Extracting data of class: 0088
# Extracting data of class: 0089
# Extracting data of class: 0090
# Extracting data of class: 0091
# Extracting data of class: 0092
# Extracting data of class: 0093
# Extracting data of class: 0094
# Extracting data of class: 0095
# Extracting data of class: 0096
# Extracting data of class: 0097
# Extracting data of class: 0098
# Extracting data of class: 0099
# Extracting data of class: 0100
# Extracting data of class: 0101
# Extracting data of class: 0102
# Extracting data of class: 0103
# Extracting data of class: 0104
# Extracting data of class: 0105
# Extracting data of class: 0106
# Extracting data of class: 0107
# Extracting data of class: 0108
# Extracting data of class: 0109
# Extracting data of class: 0110
# Extracting data of class: 0111
# Extracting data of class: 0112
# Extracting data of class: 0113
# Extracting data of class: 0114
# Extracting data of class: 0115
# Extracting data of class: 0116
# Extracting data of class: 0117
# Extracting data of class: 0118
# Extracting data of class: 0119
# Extracting data of class: 0120
# Extracting data of class: 0121
# Extracting data of class: 0122
# Extracting data of class: 0123
# Extracting data of class: 0124
# Extracting data of class: 0125
# Extracting data of class: 0126
# Extracting data of class: 0127
# Extracting data of class: 0128
# Extracting data of class: 0129
# Extracting data of class: 0130
# Extracting data of class: 0131
# Extracting data of class: 0132
# Extracting data of class: 0133
# Extracting data of class: 0134
# Extracting data of class: 0135
# Extracting data of class: 0136
# Extracting data of class: 0137
# Extracting data of class: 0138
# Extracting data of class: 0139
# Extracting data of class: 0140
# Extracting data of class: 0141
# Extracting data of class: 0142
# Extracting data of class: 0143
# Extracting data of class: 0144
# Extracting data of class: 0145
# Extracting data of class: 0146
# Extracting data of class: 0147
# Extracting data of class: 0148
# Extracting data of class: 0149
# Extracting data of class: 0150
# Extracting data of class: 0151
# Extracting data of class: 0152
# Extracting data of class: 0153
# Extracting data of class: 0154
# Extracting data of class: 0155
# Extracting data of class: 0156
# Extracting data of class: 0157
# Extracting data of class: 0158
# Extracting data of class: 0159
# Extracting data of class: 0160
# Extracting data of class: 0161
# Extracting data of class: 0162
# Extracting data of class: 0163
# Extracting data of class: 0164
# Extracting data of class: 0165
# Extracting data of class: 0166
# Extracting data of class: 0167
# Extracting data of class: 0168
# Extracting data of class: 0169
# Extracting data of class: 0170
# The extraction for signer  03   train  dataset is complete
# Extracting data of class: 0071
# Extracting data of class: 0072
# Extracting data of class: 0073
# Extracting data of class: 0074
# Extracting data of class: 0075
# Extracting data of class: 0076
# Extracting data of class: 0077
# Extracting data of class: 0078
# Extracting data of class: 0079
# Extracting data of class: 0080
# Extracting data of class: 0081
# Extracting data of class: 0082
# Extracting data of class: 0083
# Extracting data of class: 0084
# Extracting data of class: 0085
# Extracting data of class: 0086
# Extracting data of class: 0087
# Extracting data of class: 0088
# Extracting data of class: 0089
# Extracting data of class: 0090
# Extracting data of class: 0091
# Extracting data of class: 0092
# Extracting data of class: 0093
# Extracting data of class: 0094
# Extracting data of class: 0095
# Extracting data of class: 0096
# Extracting data of class: 0097
# Extracting data of class: 0098
# Extracting data of class: 0099
# Extracting data of class: 0100
# Extracting data of class: 0101
# Extracting data of class: 0102
# Extracting data of class: 0103
# Extracting data of class: 0104
# Extracting data of class: 0105
# Extracting data of class: 0106
# Extracting data of class: 0107
# Extracting data of class: 0108
# Extracting data of class: 0109
# Extracting data of class: 0110
# Extracting data of class: 0111
# Extracting data of class: 0112
# Extracting data of class: 0113
# Extracting data of class: 0114
# Extracting data of class: 0115
# Extracting data of class: 0116
# Extracting data of class: 0117
# Extracting data of class: 0118
# Extracting data of class: 0119
# Extracting data of class: 0120
# Extracting data of class: 0121
# Extracting data of class: 0122
# Extracting data of class: 0123
# Extracting data of class: 0124
# Extracting data of class: 0125
# Extracting data of class: 0126
# Extracting data of class: 0127
# Extracting data of class: 0128
# Extracting data of class: 0129
# Extracting data of class: 0130
# Extracting data of class: 0131
# Extracting data of class: 0132
# Extracting data of class: 0133
# Extracting data of class: 0134
# Extracting data of class: 0135
# Extracting data of class: 0136
# Extracting data of class: 0137
# Extracting data of class: 0138
# Extracting data of class: 0139
# Extracting data of class: 0140
# Extracting data of class: 0141
# Extracting data of class: 0142
# Extracting data of class: 0143
# Extracting data of class: 0144
# Extracting data of class: 0145
# Extracting data of class: 0146
# Extracting data of class: 0147
# Extracting data of class: 0148
# Extracting data of class: 0149
# Extracting data of class: 0150
# Extracting data of class: 0151
# Extracting data of class: 0152
# Extracting data of class: 0153
# Extracting data of class: 0154
# Extracting data of class: 0155
# Extracting data of class: 0156
# Extracting data of class: 0157
# Extracting data of class: 0158
# Extracting data of class: 0159
# Extracting data of class: 0160
# Extracting data of class: 0161
# Extracting data of class: 0162
# Extracting data of class: 0163
# Extracting data of class: 0164
# Extracting data of class: 0165
# Extracting data of class: 0166
# Extracting data of class: 0167
# Extracting data of class: 0168
# Extracting data of class: 0169
# Extracting data of class: 0170
# The extraction for signer  03   test  dataset is complete

# %% [markdown]
# # Save Data

# %% [markdown]
# For InceptionV3

# %%
np.savez(r"C:\Users\omtam\Downloads\InceptionV3_Signer_1",signer_1_train_features , signer_1_train_labels , signer_1_test_features , signer_1_test_labels)
np.savez(r"C:\Users\omtam\Downloads\InceptionV3_Signer_2",signer_2_train_features , signer_2_train_labels , signer_2_test_features , signer_2_test_labels)
np.savez(r"C:\Users\omtam\Downloads\InceptionV3_Signer_3",signer_3_train_features , signer_3_train_labels , signer_3_test_features , signer_3_test_labels)

# %% [markdown]
# For EfficientNetB2

# %%
np.savez(r"C:\Users\omtam\Downloads\EfficientNetB2_Signer_1",signer_1_train_features , signer_1_train_labels , signer_1_test_features , signer_1_test_labels)
np.savez(r"C:\Users\omtam\Downloads\EfficientNetB2_Signer_2",signer_2_train_features , signer_2_train_labels , signer_2_test_features , signer_2_test_labels)
np.savez(r"C:\Users\omtam\Downloads\EfficientNetB2_Signer_3",signer_3_train_features , signer_3_train_labels , signer_3_test_features , signer_3_test_labels)

# %% [markdown]
# # Load Data

# %% [markdown]
# For InceptionV3

# %%
Signer_1_files = np.load(r"C:\Users\omtam\Downloads\EfficientNetB2_Signer_1.npz")
Signer_2_files = np.load(r"C:\Users\omtam\Downloads\EfficientNetB2_Signer_2.npz")
Signer_3_files = np.load(r"C:\Users\omtam\Downloads\EfficientNetB2_Signer_3.npz")

# %% [markdown]
# For EfficientNetB2

# %%
Signer_1_files = np.load(r"C:\Users\omtam\Downloads\InceptionV3_Signer_1.npz")
Signer_2_files = np.load(r"C:\Users\omtam\Downloads\InceptionV3_Signer_2.npz")
Signer_3_files = np.load(r"C:\Users\omtam\Downloads\InceptionV3_Signer_3.npz")

# %%
signer_1_train_features = Signer_1_files['arr_0']
signer_1_train_labels = Signer_1_files['arr_1']
signer_1_test_features = Signer_1_files['arr_2']
signer_1_test_labels = Signer_1_files['arr_3']

# %%
signer_2_train_features = Signer_2_files['arr_0']
signer_2_train_labels = Signer_2_files['arr_1']
signer_2_test_features = Signer_2_files['arr_2']
signer_2_test_labels = Signer_2_files['arr_3']

# %%
signer_3_train_features = Signer_3_files['arr_0']
signer_3_train_labels = Signer_3_files['arr_1']
signer_3_test_features = Signer_3_files['arr_2']
signer_3_test_labels = Signer_3_files['arr_3']

# %% [markdown]
# # Build the model

# %%
# Utility for our sequence model.
def create_sequence_model(trainx):

 

    frame_features_input = keras.Input((trainx.shape[1],trainx.shape[2]))

 

    #Model Architecture 
    x = keras.layers.LSTM(150,return_sequences=True)(frame_features_input)
    x = keras.layers.Dropout(0.3)(x)
    x = keras.layers.Dense(150, activation="tanh")(x)
    x = keras.layers.Dropout(0.3)(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Dropout(0.3)(x)
    x = keras.layers.Dense(150, activation="tanh")(x)
    x = keras.layers.Dropout(0.3)(x)
    x = keras.layers.LSTM(150,return_sequences=True)(x)
    x = keras.layers.Dropout(0.3)(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Dense(150, activation="tanh")(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.LSTM(150)(x)
    x = keras.layers.Dropout(0.3)(x)
    x = keras.layers.BatchNormalization()(x)
    output = keras.layers.Dense(len(Classes_list), activation="softmax")(x)

 
    #creating inistance of the model
    rnn_model = keras.Model(frame_features_input, output)
    
    adamOptimizer = keras.optimizers.Adam(lr = 0.004)                    #SGD optimizer
    rnn_model.compile(loss="sparse_categorical_crossentropy", optimizer=adamOptimizer , metrics=["accuracy"])

 

    return rnn_model

 


# Utility for running experiments.
def run_experiment(trainx,trainy,testx,testy):
    earlyStopper = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10) 
    trainx, X_validation, trainy, y_validation = train_test_split(trainx, trainy, test_size=0.20, random_state=201827000)

    #filepath = r"C:\Users\omtam\Downloads"
    
    #checkpoint = keras.callbacks.ModelCheckpoint(
        #filepath, save_weights_only=True, save_best_only=True, verbose=1 )
    
    # create the RNN model
    seq_model = create_sequence_model(trainx)

 
    # start the training
    seq_model.fit(
        trainx,
        trainy,
        validation_data=(X_validation, y_validation),
        epochs=25,
        batch_size=64
    #callbacks=[earlyStopper,checkpoint]
    )

 

    _, accuracy = seq_model.evaluate(testx, testy)

    print(f"Test accuracy: {round(accuracy * 100, 2)}%")

# %% [markdown]
# # Signer 1 accuracy / InceptionV3

# %%
run_experiment(signer_1_train_features , signer_1_train_labels, signer_1_test_features , signer_1_test_labels)
# Out:
# Epoch 1/25
# 55/55 [==============================] - 8s 30ms/step - loss: 3.7663 - accuracy: 0.1121
# Epoch 2/25
# 55/55 [==============================] - 2s 28ms/step - loss: 2.0750 - accuracy: 0.3839
# Epoch 3/25
# 55/55 [==============================] - 2s 28ms/step - loss: 1.2406 - accuracy: 0.5998
# Epoch 4/25
# 55/55 [==============================] - 2s 28ms/step - loss: 0.8654 - accuracy: 0.7213
# Epoch 5/25
# 55/55 [==============================] - 2s 28ms/step - loss: 0.7061 - accuracy: 0.7590
# Epoch 6/25
# 55/55 [==============================] - 2s 28ms/step - loss: 0.5831 - accuracy: 0.7932
# Epoch 7/25
# 55/55 [==============================] - 2s 29ms/step - loss: 0.4243 - accuracy: 0.8571
# Epoch 8/25
# 55/55 [==============================] - 2s 38ms/step - loss: 0.3468 - accuracy: 0.8893
# Epoch 9/25
# 55/55 [==============================] - 2s 34ms/step - loss: 0.3119 - accuracy: 0.8987
# Epoch 10/25
# 55/55 [==============================] - 2s 31ms/step - loss: 0.1922 - accuracy: 0.9378
# Epoch 11/25
# 55/55 [==============================] - 2s 32ms/step - loss: 0.2322 - accuracy: 0.9295
# Epoch 12/25
# 55/55 [==============================] - 2s 29ms/step - loss: 0.2732 - accuracy: 0.9130
# Epoch 13/25
# 55/55 [==============================] - 2s 34ms/step - loss: 0.3127 - accuracy: 0.8962
# Epoch 14/25
# 55/55 [==============================] - 2s 34ms/step - loss: 0.2536 - accuracy: 0.9173
# Epoch 15/25
# 55/55 [==============================] - 2s 29ms/step - loss: 0.2177 - accuracy: 0.9301
# Epoch 16/25
# 55/55 [==============================] - 1s 27ms/step - loss: 0.1216 - accuracy: 0.9661
# Epoch 17/25
# 55/55 [==============================] - 1s 27ms/step - loss: 0.1471 - accuracy: 0.9555
# Epoch 18/25
# 55/55 [==============================] - 2s 28ms/step - loss: 0.2200 - accuracy: 0.9304
# Epoch 19/25
# 55/55 [==============================] - 2s 28ms/step - loss: 0.2152 - accuracy: 0.9353
# Epoch 20/25
# 55/55 [==============================] - 2s 29ms/step - loss: 0.1730 - accuracy: 0.9435
# Epoch 21/25
# 55/55 [==============================] - 2s 28ms/step - loss: 0.1637 - accuracy: 0.9489
# Epoch 22/25
# 55/55 [==============================] - 2s 28ms/step - loss: 0.1406 - accuracy: 0.9584
# Epoch 23/25
# 55/55 [==============================] - 2s 28ms/step - loss: 0.1231 - accuracy: 0.9621
# Epoch 24/25
# 55/55 [==============================] - 2s 27ms/step - loss: 0.1910 - accuracy: 0.9410
# Epoch 25/25
# 55/55 [==============================] - 2s 28ms/step - loss: 0.1663 - accuracy: 0.9524
# 25/25 [==============================] - 1s 9ms/step - loss: 0.4430 - accuracy: 0.9312
# Test accuracy: 93.12%

# %% [markdown]
# # Signer 1 accuracy / EfficientNetB2

# %%
run_experiment(signer_1_train_features , signer_1_train_labels, signer_1_test_features , signer_1_test_labels)
# Out:
# C:\Users\omtam\.conda\envs\pytorch\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/25
# 55/55 [==============================] - 10s 33ms/step - loss: 3.9077 - accuracy: 0.0987
# Epoch 2/25
# 55/55 [==============================] - 2s 30ms/step - loss: 2.2067 - accuracy: 0.3431
# Epoch 3/25
# 55/55 [==============================] - 2s 32ms/step - loss: 1.6074 - accuracy: 0.4718
# Epoch 4/25
# 55/55 [==============================] - 2s 30ms/step - loss: 1.4776 - accuracy: 0.5214
# Epoch 5/25
# 55/55 [==============================] - 2s 28ms/step - loss: 1.4104 - accuracy: 0.5476
# Epoch 6/25
# 55/55 [==============================] - 2s 29ms/step - loss: 1.2404 - accuracy: 0.5904
# Epoch 7/25
# 55/55 [==============================] - 2s 29ms/step - loss: 1.0737 - accuracy: 0.6435
# Epoch 8/25
# 55/55 [==============================] - 2s 30ms/step - loss: 1.0022 - accuracy: 0.6631
# Epoch 9/25
# 55/55 [==============================] - 2s 30ms/step - loss: 0.9003 - accuracy: 0.6991
# Epoch 10/25
# 55/55 [==============================] - 2s 30ms/step - loss: 0.8291 - accuracy: 0.7188
# Epoch 11/25
# 55/55 [==============================] - 2s 30ms/step - loss: 0.8614 - accuracy: 0.7099
# Epoch 12/25
# 55/55 [==============================] - 2s 33ms/step - loss: 0.7859 - accuracy: 0.7339
# Epoch 13/25
# 55/55 [==============================] - 2s 32ms/step - loss: 0.7323 - accuracy: 0.7561
# Epoch 14/25
# 55/55 [==============================] - 2s 29ms/step - loss: 0.7414 - accuracy: 0.7524
# Epoch 15/25
# 55/55 [==============================] - 2s 33ms/step - loss: 0.5891 - accuracy: 0.7989
# Epoch 16/25
# 55/55 [==============================] - 2s 29ms/step - loss: 0.6908 - accuracy: 0.7781
# Epoch 17/25
# 55/55 [==============================] - 2s 30ms/step - loss: 0.6304 - accuracy: 0.7906
# Epoch 18/25
# 55/55 [==============================] - 2s 31ms/step - loss: 0.7091 - accuracy: 0.7701
# Epoch 19/25
# 55/55 [==============================] - 2s 29ms/step - loss: 0.7371 - accuracy: 0.7561
# Epoch 20/25
# 55/55 [==============================] - 2s 28ms/step - loss: 0.6139 - accuracy: 0.7906
# Epoch 21/25
# 55/55 [==============================] - 2s 33ms/step - loss: 0.4971 - accuracy: 0.8388
# Epoch 22/25
# 55/55 [==============================] - 2s 29ms/step - loss: 0.4748 - accuracy: 0.8454
# Epoch 23/25
# 55/55 [==============================] - 2s 29ms/step - loss: 0.5565 - accuracy: 0.8240
# Epoch 24/25
# 55/55 [==============================] - 2s 29ms/step - loss: 0.6288 - accuracy: 0.7878
# Epoch 25/25
# 55/55 [==============================] - 2s 29ms/step - loss: 0.6600 - accuracy: 0.7832
# 25/25 [==============================] - 2s 10ms/step - loss: 1.3312 - accuracy: 0.6475
# Test accuracy: 64.75%

# %% [markdown]
# # Signer 2 accuracy / InceptionV3

# %%
run_experiment(signer_2_train_features , signer_2_train_labels, signer_2_test_features , signer_2_test_labels)
# Out:
# Epoch 1/25
# 56/56 [==============================] - 7s 27ms/step - loss: 4.6762 - accuracy: 0.0322
# Epoch 2/25
# 56/56 [==============================] - 2s 27ms/step - loss: 3.7237 - accuracy: 0.1329
# Epoch 3/25
# 56/56 [==============================] - 1s 26ms/step - loss: 2.8270 - accuracy: 0.3273
# Epoch 4/25
# 56/56 [==============================] - 2s 27ms/step - loss: 2.0752 - accuracy: 0.5351
# Epoch 5/25
# 56/56 [==============================] - 2s 27ms/step - loss: 1.4814 - accuracy: 0.7185
# Epoch 6/25
# 56/56 [==============================] - 2s 27ms/step - loss: 1.0272 - accuracy: 0.8275
# Epoch 7/25
# 56/56 [==============================] - 2s 29ms/step - loss: 0.7182 - accuracy: 0.9055
# Epoch 8/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.5042 - accuracy: 0.9422
# Epoch 9/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.3706 - accuracy: 0.9669
# Epoch 10/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.3292 - accuracy: 0.9661
# Epoch 11/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.2282 - accuracy: 0.9829
# Epoch 12/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.2173 - accuracy: 0.9798
# Epoch 13/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.2224 - accuracy: 0.9745
# Epoch 14/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.1740 - accuracy: 0.9762
# Epoch 15/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.1535 - accuracy: 0.9829
# Epoch 16/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.0910 - accuracy: 0.9947
# Epoch 17/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.0852 - accuracy: 0.9944
# Epoch 18/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.1030 - accuracy: 0.9874
# Epoch 19/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.0644 - accuracy: 0.9947
# Epoch 20/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.1225 - accuracy: 0.9804
# Epoch 21/25
# 56/56 [==============================] - 1s 27ms/step - loss: 0.1253 - accuracy: 0.9778
# Epoch 22/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.0985 - accuracy: 0.9840
# Epoch 23/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.1418 - accuracy: 0.9708
# Epoch 24/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.0955 - accuracy: 0.9857
# Epoch 25/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.0482 - accuracy: 0.9947
# 25/25 [==============================] - 1s 9ms/step - loss: 0.0463 - accuracy: 0.9950
# Test accuracy: 99.5%

# %% [markdown]
# # Signer 2 accuracy / EfficientNetB2

# %%
run_experiment(signer_2_train_features , signer_2_train_labels, signer_2_test_features , signer_2_test_labels)
# Out:
# Epoch 1/25
# 56/56 [==============================] - 8s 32ms/step - loss: 3.9544 - accuracy: 0.0763
# Epoch 2/25
# 56/56 [==============================] - 2s 31ms/step - loss: 2.5493 - accuracy: 0.2406
# Epoch 3/25
# 56/56 [==============================] - 2s 31ms/step - loss: 1.7664 - accuracy: 0.4518
# Epoch 4/25
# 56/56 [==============================] - 2s 36ms/step - loss: 1.4857 - accuracy: 0.5163
# Epoch 5/25
# 56/56 [==============================] - 2s 33ms/step - loss: 1.2915 - accuracy: 0.5726
# Epoch 6/25
# 56/56 [==============================] - 2s 31ms/step - loss: 1.0915 - accuracy: 0.6282
# Epoch 7/25
# 56/56 [==============================] - 2s 29ms/step - loss: 1.0416 - accuracy: 0.6584
# Epoch 8/25
# 56/56 [==============================] - 2s 34ms/step - loss: 0.8902 - accuracy: 0.6999
# Epoch 9/25
# 56/56 [==============================] - 2s 31ms/step - loss: 0.8785 - accuracy: 0.7064
# Epoch 10/25
# 56/56 [==============================] - 2s 38ms/step - loss: 0.6831 - accuracy: 0.7658
# Epoch 11/25
# 56/56 [==============================] - 2s 35ms/step - loss: 0.6052 - accuracy: 0.8001
# Epoch 12/25
# 56/56 [==============================] - 2s 38ms/step - loss: 0.5731 - accuracy: 0.8228
# Epoch 13/25
# 56/56 [==============================] - 2s 34ms/step - loss: 0.5383 - accuracy: 0.8270
# Epoch 14/25
# 56/56 [==============================] - 2s 33ms/step - loss: 0.6025 - accuracy: 0.8087
# Epoch 15/25
# 56/56 [==============================] - 2s 32ms/step - loss: 0.5076 - accuracy: 0.8284
# Epoch 16/25
# 56/56 [==============================] - 2s 33ms/step - loss: 0.5671 - accuracy: 0.8188
# Epoch 17/25
# 56/56 [==============================] - 2s 33ms/step - loss: 0.6688 - accuracy: 0.7860
# Epoch 18/25
# 56/56 [==============================] - 2s 32ms/step - loss: 0.6350 - accuracy: 0.7916
# Epoch 19/25
# 56/56 [==============================] - 2s 29ms/step - loss: 0.7417 - accuracy: 0.7745
# Epoch 20/25
# 56/56 [==============================] - 2s 32ms/step - loss: 0.5049 - accuracy: 0.8402
# Epoch 21/25
# 56/56 [==============================] - 2s 30ms/step - loss: 0.4070 - accuracy: 0.8727
# Epoch 22/25
# 56/56 [==============================] - 2s 30ms/step - loss: 0.4203 - accuracy: 0.8688
# Epoch 23/25
# 56/56 [==============================] - 2s 30ms/step - loss: 0.4840 - accuracy: 0.8477
# Epoch 24/25
# 56/56 [==============================] - 2s 30ms/step - loss: 0.4564 - accuracy: 0.8519
# Epoch 25/25
# 56/56 [==============================] - 2s 30ms/step - loss: 0.3928 - accuracy: 0.8763
# 25/25 [==============================] - 2s 11ms/step - loss: 0.5525 - accuracy: 0.8200
# Test accuracy: 82.0%

# %% [markdown]
# # Signer 3 accuracy / InceptionV3

# %%
run_experiment(signer_3_train_features , signer_3_train_labels, signer_3_test_features , signer_3_test_labels)
# Out:
# Epoch 1/25
# 56/56 [==============================] - 7s 28ms/step - loss: 4.7381 - accuracy: 0.0293
# Epoch 2/25
# 56/56 [==============================] - 2s 27ms/step - loss: 3.8048 - accuracy: 0.1201
# Epoch 3/25
# 56/56 [==============================] - 2s 28ms/step - loss: 2.9815 - accuracy: 0.2738
# Epoch 4/25
# 56/56 [==============================] - 2s 28ms/step - loss: 2.2482 - accuracy: 0.4577
# Epoch 5/25
# 56/56 [==============================] - 2s 28ms/step - loss: 1.6162 - accuracy: 0.6526
# Epoch 6/25
# 56/56 [==============================] - 2s 28ms/step - loss: 1.1709 - accuracy: 0.7671
# Epoch 7/25
# 56/56 [==============================] - 1s 27ms/step - loss: 0.8184 - accuracy: 0.8644
# Epoch 8/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.5897 - accuracy: 0.9160
# Epoch 9/25
# 56/56 [==============================] - 2s 30ms/step - loss: 0.4697 - accuracy: 0.9388
# Epoch 10/25
# 56/56 [==============================] - 2s 29ms/step - loss: 0.3864 - accuracy: 0.9461
# Epoch 11/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.3281 - accuracy: 0.9532
# Epoch 12/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.2525 - accuracy: 0.9676
# Epoch 13/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.2050 - accuracy: 0.9780
# Epoch 14/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.1895 - accuracy: 0.9741
# Epoch 15/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.1355 - accuracy: 0.9882
# Epoch 16/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.1187 - accuracy: 0.9896
# Epoch 17/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.1024 - accuracy: 0.9910
# Epoch 18/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.0887 - accuracy: 0.9918
# Epoch 19/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.0717 - accuracy: 0.9935
# Epoch 20/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.0657 - accuracy: 0.9941
# Epoch 21/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.0713 - accuracy: 0.9918
# Epoch 22/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.0944 - accuracy: 0.9853
# Epoch 23/25
# 56/56 [==============================] - 2s 27ms/step - loss: 0.1355 - accuracy: 0.9755
# Epoch 24/25
# 56/56 [==============================] - 2s 30ms/step - loss: 0.1091 - accuracy: 0.9788
# Epoch 25/25
# 56/56 [==============================] - 1s 26ms/step - loss: 0.0838 - accuracy: 0.9870
# 25/25 [==============================] - 1s 9ms/step - loss: 4.8826e-04 - accuracy: 1.0000
# Test accuracy: 100.0%

# %% [markdown]
# # Signer 3 accuracy / EfficientNetB2

# %%
run_experiment(signer_3_train_features , signer_3_train_labels, signer_3_test_features , signer_3_test_labels)
# Out:
# Epoch 1/25
# 56/56 [==============================] - 7s 30ms/step - loss: 3.8764 - accuracy: 0.0973
# Epoch 2/25
# 56/56 [==============================] - 2s 30ms/step - loss: 2.2739 - accuracy: 0.3088
# Epoch 3/25
# 56/56 [==============================] - 2s 30ms/step - loss: 1.5340 - accuracy: 0.4941
# Epoch 4/25
# 56/56 [==============================] - 2s 29ms/step - loss: 1.1509 - accuracy: 0.6173
# Epoch 5/25
# 56/56 [==============================] - 2s 30ms/step - loss: 0.9640 - accuracy: 0.6729
# Epoch 6/25
# 56/56 [==============================] - 2s 30ms/step - loss: 0.8478 - accuracy: 0.7140
# Epoch 7/25
# 56/56 [==============================] - 2s 30ms/step - loss: 0.8877 - accuracy: 0.7084
# Epoch 8/25
# 56/56 [==============================] - 2s 29ms/step - loss: 0.8454 - accuracy: 0.7129
# Epoch 9/25
# 56/56 [==============================] - 2s 29ms/step - loss: 0.6473 - accuracy: 0.7840
# Epoch 10/25
# 56/56 [==============================] - 2s 30ms/step - loss: 0.5716 - accuracy: 0.8026
# Epoch 11/25
# 56/56 [==============================] - 2s 29ms/step - loss: 0.6701 - accuracy: 0.7845
# Epoch 12/25
# 56/56 [==============================] - 2s 31ms/step - loss: 0.7029 - accuracy: 0.7611
# Epoch 13/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.7288 - accuracy: 0.7549
# Epoch 14/25
# 56/56 [==============================] - 2s 32ms/step - loss: 0.5052 - accuracy: 0.8237
# Epoch 15/25
# 56/56 [==============================] - 2s 31ms/step - loss: 0.4960 - accuracy: 0.8381
# Epoch 16/25
# 56/56 [==============================] - 2s 29ms/step - loss: 0.4704 - accuracy: 0.8395
# Epoch 17/25
# 56/56 [==============================] - 2s 28ms/step - loss: 0.4310 - accuracy: 0.8545
# Epoch 18/25
# 56/56 [==============================] - 2s 29ms/step - loss: 0.4175 - accuracy: 0.8607
# Epoch 19/25
# 56/56 [==============================] - 2s 29ms/step - loss: 0.3998 - accuracy: 0.8672
# Epoch 20/25
# 56/56 [==============================] - 2s 29ms/step - loss: 0.5311 - accuracy: 0.8319
# Epoch 21/25
# 56/56 [==============================] - 2s 29ms/step - loss: 0.6407 - accuracy: 0.7961
# Epoch 22/25
# 56/56 [==============================] - 2s 30ms/step - loss: 0.6537 - accuracy: 0.7992
# Epoch 23/25
# 56/56 [==============================] - 2s 30ms/step - loss: 0.5141 - accuracy: 0.8333
# Epoch 24/25
# 56/56 [==============================] - 2s 29ms/step - loss: 0.4305 - accuracy: 0.8615
# Epoch 25/25
# 56/56 [==============================] - 2s 33ms/step - loss: 0.5269 - accuracy: 0.8435
# 25/25 [==============================] - 1s 9ms/step - loss: 0.2794 - accuracy: 0.9187
# Test accuracy: 91.87%

# %% [markdown]
# # Signer 1 ( traind on signer 2 and 3 ) accuracy / InceptionV3

# %%
#combining all data from signer 2 and 3 
signer_2_3_features = np.concatenate((signer_2_train_features, signer_3_train_features)) 
signer_2_3_labels = np.concatenate((signer_2_train_labels, signer_3_train_labels))

# %%
signer_1_test_features_combine = np.concatenate((signer_1_train_features,signer_1_test_features))
signer_1_test_labels_combine = np.concatenate((signer_1_train_labels,signer_1_test_labels))

# %%
run_experiment(signer_2_3_features , signer_2_3_labels, signer_1_test_features , signer_1_test_labels)
# Out:
# Epoch 1/25
# 112/112 [==============================] - 9s 30ms/step - loss: 3.1288 - accuracy: 0.1977
# Epoch 2/25
# 112/112 [==============================] - 4s 31ms/step - loss: 1.4582 - accuracy: 0.5368
# Epoch 3/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.8665 - accuracy: 0.7096
# Epoch 4/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.6929 - accuracy: 0.7679
# Epoch 5/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.5107 - accuracy: 0.8363
# Epoch 6/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.4144 - accuracy: 0.8642
# Epoch 7/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.5386 - accuracy: 0.8279
# Epoch 8/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.5433 - accuracy: 0.8314
# Epoch 9/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.3617 - accuracy: 0.8823
# Epoch 10/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.3503 - accuracy: 0.8888
# Epoch 11/25
# 112/112 [==============================] - 3s 31ms/step - loss: 0.3960 - accuracy: 0.8796
# Epoch 12/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.3084 - accuracy: 0.8997
# Epoch 13/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.3265 - accuracy: 0.8990
# Epoch 14/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2493 - accuracy: 0.9231
# Epoch 15/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2241 - accuracy: 0.9293
# Epoch 16/25
# 112/112 [==============================] - 3s 31ms/step - loss: 0.2808 - accuracy: 0.9166
# Epoch 17/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2532 - accuracy: 0.9207
# Epoch 18/25
# 112/112 [==============================] - 3s 31ms/step - loss: 0.2044 - accuracy: 0.9393
# Epoch 19/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.3265 - accuracy: 0.9010
# Epoch 20/25
# 112/112 [==============================] - 3s 31ms/step - loss: 0.2641 - accuracy: 0.9180
# Epoch 21/25
# 112/112 [==============================] - 4s 32ms/step - loss: 0.2663 - accuracy: 0.9168
# Epoch 22/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.1926 - accuracy: 0.9412
# Epoch 23/25
# 112/112 [==============================] - 3s 29ms/step - loss: 0.2934 - accuracy: 0.9128
# Epoch 24/25
# 112/112 [==============================] - 3s 29ms/step - loss: 0.2317 - accuracy: 0.9339
# Epoch 25/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.2281 - accuracy: 0.9318
# 25/25 [==============================] - 1s 10ms/step - loss: 5.9967 - accuracy: 0.2625
# Test accuracy: 26.25%

# %% [markdown]
# # Signer 1 ( traind on signer 2 and 3 ) accuracy / EfficientNetB2

# %%
run_experiment(signer_2_3_features , signer_2_3_labels, signer_1_test_features , signer_1_test_labels)
# Out:
# Epoch 1/25
# 112/112 [==============================] - 10s 32ms/step - loss: 3.6914 - accuracy: 0.1028
# Epoch 2/25
# 112/112 [==============================] - 3s 30ms/step - loss: 2.4194 - accuracy: 0.2777
# Epoch 3/25
# 112/112 [==============================] - 4s 33ms/step - loss: 1.8218 - accuracy: 0.4068
# Epoch 4/25
# 112/112 [==============================] - 4s 32ms/step - loss: 1.7285 - accuracy: 0.4414
# Epoch 5/25
# 112/112 [==============================] - 3s 30ms/step - loss: 1.6630 - accuracy: 0.4599
# Epoch 6/25
# 112/112 [==============================] - 4s 33ms/step - loss: 1.3918 - accuracy: 0.5325
# Epoch 7/25
# 112/112 [==============================] - 3s 30ms/step - loss: 1.5032 - accuracy: 0.5082
# Epoch 8/25
# 112/112 [==============================] - 4s 33ms/step - loss: 1.1840 - accuracy: 0.5851
# Epoch 9/25
# 112/112 [==============================] - 3s 30ms/step - loss: 1.0744 - accuracy: 0.6294
# Epoch 10/25
# 112/112 [==============================] - 3s 30ms/step - loss: 1.0633 - accuracy: 0.6332
# Epoch 11/25
# 112/112 [==============================] - 3s 30ms/step - loss: 1.0260 - accuracy: 0.6481
# Epoch 12/25
# 112/112 [==============================] - 4s 34ms/step - loss: 0.9351 - accuracy: 0.6756
# Epoch 13/25
# 112/112 [==============================] - 3s 31ms/step - loss: 0.9785 - accuracy: 0.6676
# Epoch 14/25
# 112/112 [==============================] - 4s 32ms/step - loss: 0.7982 - accuracy: 0.7172
# Epoch 15/25
# 112/112 [==============================] - 3s 31ms/step - loss: 0.7679 - accuracy: 0.7330
# Epoch 16/25
# 112/112 [==============================] - 3s 30ms/step - loss: 0.7195 - accuracy: 0.7494
# Epoch 17/25
# 112/112 [==============================] - 3s 29ms/step - loss: 0.7724 - accuracy: 0.7316
# Epoch 18/25
# 112/112 [==============================] - 3s 31ms/step - loss: 0.7299 - accuracy: 0.7448
# Epoch 19/25
# 112/112 [==============================] - 3s 31ms/step - loss: 0.8487 - accuracy: 0.7141
# Epoch 20/25
# 112/112 [==============================] - 3s 31ms/step - loss: 0.7444 - accuracy: 0.7462
# Epoch 21/25
# 112/112 [==============================] - 4s 32ms/step - loss: 0.7038 - accuracy: 0.7624
# Epoch 22/25
# 112/112 [==============================] - 3s 29ms/step - loss: 0.7172 - accuracy: 0.7572
# Epoch 23/25
# 112/112 [==============================] - 4s 32ms/step - loss: 0.7768 - accuracy: 0.7362
# Epoch 24/25
# 112/112 [==============================] - 4s 31ms/step - loss: 0.8453 - accuracy: 0.7243
# Epoch 25/25
# 112/112 [==============================] - 3s 31ms/step - loss: 1.2919 - accuracy: 0.6043
# 25/25 [==============================] - 2s 10ms/step - loss: 4.5668 - accuracy: 0.1937
# Test accuracy: 19.37%

# %% [markdown]
# # Signer 2 (traind on signer 1 and 3 ) accuracy / InceptionV3

# %%
#combining all data from signer 1 and 3 
signer_1_3_features = np.concatenate((signer_1_train_features, signer_3_train_features)) 
signer_1_3_labels = np.concatenate((signer_1_train_labels, signer_3_train_labels))

# %%
run_experiment(signer_1_3_features , signer_1_3_labels, signer_2_test_features , signer_2_test_labels)
# Out:
# Epoch 1/25
# 111/111 [==============================] - 9s 30ms/step - loss: 3.1442 - accuracy: 0.1924
# Epoch 2/25
# 111/111 [==============================] - 3s 30ms/step - loss: 1.3945 - accuracy: 0.5623
# Epoch 3/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.8330 - accuracy: 0.7294
# Epoch 4/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.6458 - accuracy: 0.7898
# Epoch 5/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.6109 - accuracy: 0.8010
# Epoch 6/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.4460 - accuracy: 0.8542
# Epoch 7/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.4780 - accuracy: 0.8473
# Epoch 8/25
# 111/111 [==============================] - 3s 31ms/step - loss: 0.5088 - accuracy: 0.8452
# Epoch 9/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.3724 - accuracy: 0.8807
# Epoch 10/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2731 - accuracy: 0.9141
# Epoch 11/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2361 - accuracy: 0.9278
# Epoch 12/25
# 111/111 [==============================] - 3s 31ms/step - loss: 0.3739 - accuracy: 0.8861
# Epoch 13/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2691 - accuracy: 0.9149
# Epoch 14/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1939 - accuracy: 0.9370
# Epoch 15/25
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2378 - accuracy: 0.9236
# Epoch 16/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2096 - accuracy: 0.9348
# Epoch 17/25
# 111/111 [==============================] - 3s 31ms/step - loss: 0.1960 - accuracy: 0.9409
# Epoch 18/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1752 - accuracy: 0.9434
# Epoch 19/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1794 - accuracy: 0.9438
# Epoch 20/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.3127 - accuracy: 0.9064
# Epoch 21/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2374 - accuracy: 0.9256
# Epoch 22/25
# 111/111 [==============================] - 3s 31ms/step - loss: 0.2014 - accuracy: 0.9375
# Epoch 23/25
# 111/111 [==============================] - 4s 32ms/step - loss: 0.3352 - accuracy: 0.9020
# Epoch 24/25
# 111/111 [==============================] - 4s 32ms/step - loss: 0.2684 - accuracy: 0.9178
# Epoch 25/25
# 111/111 [==============================] - 3s 28ms/step - loss: 0.2590 - accuracy: 0.9212
# 25/25 [==============================] - 1s 10ms/step - loss: 5.7473 - accuracy: 0.2850
# Test accuracy: 28.5%

# %% [markdown]
# # Signer 2 (traind on signer 1 and 3 ) accuracy / EfficientNetB2

# %%
run_experiment(signer_1_3_features , signer_1_3_labels, signer_2_test_features , signer_2_test_labels)
# Out:
# Epoch 1/25
# 111/111 [==============================] - 9s 31ms/step - loss: 3.7610 - accuracy: 0.0956
# Epoch 2/25
# 111/111 [==============================] - 3s 30ms/step - loss: 2.6369 - accuracy: 0.2577
# Epoch 3/25
# 111/111 [==============================] - 3s 30ms/step - loss: 2.0555 - accuracy: 0.3644
# Epoch 4/25
# 111/111 [==============================] - 3s 30ms/step - loss: 1.9479 - accuracy: 0.4041
# Epoch 5/25
# 111/111 [==============================] - 3s 30ms/step - loss: 1.6121 - accuracy: 0.4837
# Epoch 6/25
# 111/111 [==============================] - 4s 32ms/step - loss: 1.5267 - accuracy: 0.5065
# Epoch 7/25
# 111/111 [==============================] - 3s 30ms/step - loss: 1.7193 - accuracy: 0.4575
# Epoch 8/25
# 111/111 [==============================] - 3s 31ms/step - loss: 1.3498 - accuracy: 0.5567
# Epoch 9/25
# 111/111 [==============================] - 3s 31ms/step - loss: 1.2306 - accuracy: 0.5922
# Epoch 10/25
# 111/111 [==============================] - 3s 30ms/step - loss: 1.2125 - accuracy: 0.6004
# Epoch 11/25
# 111/111 [==============================] - 3s 31ms/step - loss: 1.1329 - accuracy: 0.6156
# Epoch 12/25
# 111/111 [==============================] - 3s 30ms/step - loss: 1.1424 - accuracy: 0.6176
# Epoch 13/25
# 111/111 [==============================] - 3s 30ms/step - loss: 1.0580 - accuracy: 0.6486
# Epoch 14/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.9918 - accuracy: 0.6638
# Epoch 15/25
# 111/111 [==============================] - 3s 31ms/step - loss: 0.9612 - accuracy: 0.6761
# Epoch 16/25
# 111/111 [==============================] - 3s 31ms/step - loss: 0.9449 - accuracy: 0.6817
# Epoch 17/25
# 111/111 [==============================] - 3s 31ms/step - loss: 0.8562 - accuracy: 0.7041
# Epoch 18/25
# 111/111 [==============================] - 4s 33ms/step - loss: 0.7673 - accuracy: 0.7273
# Epoch 19/25
# 111/111 [==============================] - 4s 33ms/step - loss: 0.7150 - accuracy: 0.7490
# Epoch 20/25
# 111/111 [==============================] - 4s 33ms/step - loss: 0.7617 - accuracy: 0.7432
# Epoch 21/25
# 111/111 [==============================] - 3s 29ms/step - loss: 0.7033 - accuracy: 0.7581
# Epoch 22/25
# 111/111 [==============================] - 4s 32ms/step - loss: 0.9794 - accuracy: 0.6821
# Epoch 23/25
# 111/111 [==============================] - 3s 29ms/step - loss: 0.8957 - accuracy: 0.7065
# Epoch 24/25
# 111/111 [==============================] - 4s 32ms/step - loss: 0.9866 - accuracy: 0.6826
# Epoch 25/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.7900 - accuracy: 0.7321
# 25/25 [==============================] - 2s 11ms/step - loss: 5.7873 - accuracy: 0.1500
# Test accuracy: 15.0%

# %% [markdown]
# # Signer 3 (traind on signer 1 and 2 ) accuracy / InceptionV3

# %%
#combining all data from signer 1 and 2 
signer_1_2_features = np.concatenate((signer_1_train_features, signer_2_train_features)) 
signer_1_2_labels = np.concatenate((signer_1_train_labels, signer_2_train_labels))

# %%
run_experiment(signer_1_2_features , signer_1_2_labels, signer_3_test_features , signer_3_test_labels)
# Out:
# Epoch 1/25
# 111/111 [==============================] - 9s 31ms/step - loss: 3.0325 - accuracy: 0.2286
# Epoch 2/25
# 111/111 [==============================] - 3s 30ms/step - loss: 1.3001 - accuracy: 0.5788
# Epoch 3/25
# 111/111 [==============================] - 4s 33ms/step - loss: 0.7853 - accuracy: 0.7448
# Epoch 4/25
# 111/111 [==============================] - 4s 34ms/step - loss: 0.5603 - accuracy: 0.8170
# Epoch 5/25
# 111/111 [==============================] - 4s 32ms/step - loss: 0.4617 - accuracy: 0.8494
# Epoch 6/25
# 111/111 [==============================] - 4s 35ms/step - loss: 0.4893 - accuracy: 0.8394
# Epoch 7/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.5077 - accuracy: 0.8385
# Epoch 8/25
# 111/111 [==============================] - 4s 33ms/step - loss: 0.4499 - accuracy: 0.8586
# Epoch 9/25
# 111/111 [==============================] - 3s 29ms/step - loss: 0.3701 - accuracy: 0.8886
# Epoch 10/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2548 - accuracy: 0.9198
# Epoch 11/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.3341 - accuracy: 0.8979
# Epoch 12/25
# 111/111 [==============================] - 3s 29ms/step - loss: 0.3288 - accuracy: 0.8959
# Epoch 13/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2348 - accuracy: 0.9277
# Epoch 14/25
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2368 - accuracy: 0.9303
# Epoch 15/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2876 - accuracy: 0.9105
# Epoch 16/25
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2160 - accuracy: 0.9316
# Epoch 17/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1977 - accuracy: 0.9403
# Epoch 18/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1565 - accuracy: 0.9528
# Epoch 19/25
# 111/111 [==============================] - 3s 29ms/step - loss: 0.2704 - accuracy: 0.9211
# Epoch 20/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2220 - accuracy: 0.9354
# Epoch 21/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2058 - accuracy: 0.9354
# Epoch 22/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2330 - accuracy: 0.9303
# Epoch 23/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.2242 - accuracy: 0.9314
# Epoch 24/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.1795 - accuracy: 0.9467
# Epoch 25/25
# 111/111 [==============================] - 3s 29ms/step - loss: 0.1747 - accuracy: 0.9490
# 25/25 [==============================] - 1s 9ms/step - loss: 5.4599 - accuracy: 0.3000
# Test accuracy: 30.0%

# %% [markdown]
# # Signer 3 (traind on signer 1 and 2 ) accuracy / EfficientNetB2

# %%
run_experiment(signer_1_2_features , signer_1_2_labels, signer_3_test_features , signer_3_test_labels)
# Out:
# Epoch 1/25
# 111/111 [==============================] - 9s 30ms/step - loss: 3.7232 - accuracy: 0.1092
# Epoch 2/25
# 111/111 [==============================] - 4s 33ms/step - loss: 2.1907 - accuracy: 0.3363
# Epoch 3/25
# 111/111 [==============================] - 4s 35ms/step - loss: 1.7054 - accuracy: 0.4523
# Epoch 4/25
# 111/111 [==============================] - 4s 36ms/step - loss: 1.4323 - accuracy: 0.5279
# Epoch 5/25
# 111/111 [==============================] - 4s 33ms/step - loss: 1.2724 - accuracy: 0.5803
# Epoch 6/25
# 111/111 [==============================] - 4s 32ms/step - loss: 1.1091 - accuracy: 0.6209
# Epoch 7/25
# 111/111 [==============================] - 4s 32ms/step - loss: 1.0509 - accuracy: 0.6524
# Epoch 8/25
# 111/111 [==============================] - 3s 29ms/step - loss: 0.9147 - accuracy: 0.6951
# Epoch 9/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.8439 - accuracy: 0.7185
# Epoch 10/25
# 111/111 [==============================] - 4s 34ms/step - loss: 0.7718 - accuracy: 0.7347
# Epoch 11/25
# 111/111 [==============================] - 4s 38ms/step - loss: 0.6975 - accuracy: 0.7634
# Epoch 12/25
# 111/111 [==============================] - 3s 29ms/step - loss: 0.7021 - accuracy: 0.7663
# Epoch 13/25
# 111/111 [==============================] - 3s 29ms/step - loss: 0.6733 - accuracy: 0.7767
# Epoch 14/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.7058 - accuracy: 0.7663
# Epoch 15/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.6744 - accuracy: 0.7766
# Epoch 16/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.6661 - accuracy: 0.7815
# Epoch 17/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.7405 - accuracy: 0.7646
# Epoch 18/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.7143 - accuracy: 0.7702
# Epoch 19/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.6717 - accuracy: 0.7834
# Epoch 20/25
# 111/111 [==============================] - 3s 29ms/step - loss: 0.5963 - accuracy: 0.8080
# Epoch 21/25
# 111/111 [==============================] - 3s 29ms/step - loss: 0.5290 - accuracy: 0.8237
# Epoch 22/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.6947 - accuracy: 0.7786
# Epoch 23/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.7483 - accuracy: 0.7633
# Epoch 24/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.5930 - accuracy: 0.8054
# Epoch 25/25
# 111/111 [==============================] - 3s 30ms/step - loss: 0.5772 - accuracy: 0.8104
# 25/25 [==============================] - 1s 10ms/step - loss: 4.6918 - accuracy: 0.2463
# Test accuracy: 24.63%

# %% [markdown]
# Best accuracy for signer-dependent mode:
# 1. 93.12%
# 2. 99.5%
# 3. 100%

# %% [markdown]
# Best accuracy for signer-independent mode:
# 1. 26.5%
# 2. 28.5%
# 3. 30.0%

# %% [markdown]
# Extracting data using InceptionV3 is better than EfficientNetB2
